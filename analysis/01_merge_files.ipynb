# %% [markdown]
# ## Description
#
# In this notebook, we will pull Tennessee's raw data files which we have downloaded manually from the Tennessee Department of Education data archives (https://www.tn.gov/education/data/data-downloads.html), convert them to CSV with the naming convention topic+level+year.csv, map and merge the datafiles based on the topic, and export as CSV.

# %%
import glob 
import csv
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 50)

# %% [markdown]
# ## Pull Data From Folder
# https://www.tn.gov/education/data/data-downloads.html

# %%
all_raw_xls_files = glob.glob('../raw_data_files/*')
all_raw_xls_files.sort()

all_raw_xls_files[:5]
# Out:
# ['../raw_data_files/2017-18 ACT_school_suppressed.xlsx',
#  '../raw_data_files/201819_membership.xlsx',
#  '../raw_data_files/2020-21_tvaas_school_composite.csv',
#  '../raw_data_files/2020-21_tvaas_school_subject_level.csv',
#  '../raw_data_files/2022_school_assessment_file_suppressed_upd8-19.xlsx']

# %%
def download_rename_and_upload_as_csv(original_file_name, xls_or_csv, clean_file_name, has_xls_sheet): 
    if xls_or_csv == 'csv': 
        og_file = pd.read_csv('../raw_data_files/{}.csv'.format(original_file_name), dtype=str, index_col=None)
    else:
        if has_xls_sheet == False:
            og_file = pd.read_excel('../raw_data_files/{}.xlsx'.format(original_file_name), 
                                    dtype=str, 
                                    index_col=None)
        else:
            og_file = pd.read_excel('../raw_data_files/{}.xlsx'.format(original_file_name),
                                    dtype=str, 
                                    index_col=None,
                                    sheet_name=has_xls_sheet
                                   )
            
    og_file.to_csv('../raw_data_files_clean/{}.csv'.format(clean_file_name), encoding='utf-8', index=False)

# %%
##  Pull files and create dataframes 
def pull_files_and_create_df(raw_file_names): 
    df_list=[]
    for i in raw_file_names:
        name = i.split('/')[2].split('.')[0]
        globals()[f'df_{name}'] = pd.read_csv(i, low_memory=False)
        d = df_list.append(f'df_{name}')
    df_list.sort(reverse=True)
    return df_list

# %%
## Match file column names 
def match_files(list_of_file_names):  
    
    # change column names to lowercase and replace space with underscores
    for d in list_of_file_names: 
        globals()[d].columns = list((map(lambda x: x.lower().replace(' ', '_'),list(globals()[d]))))
    
    # create matching dataframe 
    df=[]
    for n in range(len(list_of_file_names)):
        name = list_of_file_names[n]
        total_num_cols1 = len(globals()[list_of_file_names[n]].columns)
        set_f1_cols = set((map(lambda x: "'" + x + "'", list(globals()[list_of_file_names[n]]))))
               
        if n+1 == len(list_of_file_names):
            name0 = 'NA'
            total_num_cols0 = 0
            set_f0_cols = []        
        else:
            name0 = list_of_file_names[n+1]
            total_num_cols0 = len(globals()[list_of_file_names[n+1]].columns)
            set_f0_cols = set((map(lambda x: "'" + x + "'", list(globals()[list_of_file_names[n+1]]))))
        dict = {'current_file_name': name,
                'prev_file_name': name0,
                'current_num_cols': total_num_cols1,
                'prev_num_cols': total_num_cols0,
                'current_cols': sorted(set_f1_cols),
                'prev_cols': sorted(set_f0_cols),
                'matching_columns': sorted(set_f1_cols.intersection(set_f0_cols)),
                'num_matching': len(set_f1_cols.intersection(set_f0_cols)),
                'mismatched_columns': sorted(set_f1_cols.difference(set_f0_cols)),
                'num_mismatching': len(set_f1_cols.difference(set_f0_cols))
                }
        df.append(dict)
    df_chx = pd.DataFrame(df)
    return df_chx

# %%
def df_to_change_and_merge(df_name, column_list): 
    appended_data = []
    
    df_files = [names for names in df_all_files if names.startswith(df_name)]
    df_files
    
    for d in df_files:
        globals()[d] = globals()[d][column_list]
        globals()[d]['file_source'] = d
        globals()[d]['file_year'] = d.split('_')[-1]
        appended_data.append(globals()[d])
    globals()[df_name] = pd.concat(appended_data).copy()
    globals()[df_name] = pd.merge(globals()[df_name], df_directory_school_2022[['district_number', 'school_number','updated_district_number','school_type','status']], on=['district_number', 'school_number'], how='left')
    globals()[df_name].to_csv('../raw_data_files_clean/merged_{}.csv'.format(df_name[3:]), encoding='utf-8', index=False)

# %%
'df_tvaas_composite_subject_school_2021'[3:]
# Out:
# 'tvaas_composite_subject_school_2021'

# %%
# ## This cell is pretty manual because the file names are not consistent. 
# ## However, I can see the utility of creating lists and loops for 
# ## file names and file types to make it less manual. 


# download_rename_and_upload_as_csv('data_2015_school_base', 
#                                   'xlsx',
#                                   'assessment_school_2015', 
#                                   False)

# %%
cleaned_csv_files = glob.glob('../raw_data_files_clean/*.csv')
cleaned_csv_files.sort()
cleaned_csv_files[:5]
# Out:
# ['../raw_data_files_clean/act_school_2017.csv',
#  '../raw_data_files_clean/act_school_2018.csv',
#  '../raw_data_files_clean/act_school_2019.csv',
#  '../raw_data_files_clean/act_school_2020.csv',
#  '../raw_data_files_clean/act_school_2021.csv']

# %%
# %%time
df_all_files = pull_files_and_create_df(cleaned_csv_files)
# Out:
# CPU times: user 19.9 s, sys: 7.24 s, total: 27.1 s
# Wall time: 30.5 s

# %%
df_all_files[:10]
# Out:
# ['df_tvaas_composite_subject_school_2022',
#  'df_tvaas_composite_subject_school_2021',
#  'df_tvaas_composite_subject_school_2019',
#  'df_tvaas_composite_subject_school_2018',
#  'df_tvaas_composite_subject_school_2017',
#  'df_tvaas_composite_school_2022',
#  'df_tvaas_composite_school_2021',
#  'df_tvaas_composite_school_2019',
#  'df_tvaas_composite_school_2018',
#  'df_tvaas_composite_school_2017']

# %%
df_file_name_specs_check = match_files(df_all_files)

# %%
# with pd.ExcelWriter('../data_for_analysis/file_specs.xlsx') as writer:  
#     df_file_name_specs_check.to_excel(writer, sheet_name='file_columns_comparisons')

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', None)
df_file_name_specs_check #.head()
# Out:
#                            current_file_name  \
# 0     df_tvaas_composite_subject_school_2022
# 1     df_tvaas_composite_subject_school_2021
# 2     df_tvaas_composite_subject_school_2019
# 3     df_tvaas_composite_subject_school_2018
# 4     df_tvaas_composite_subject_school_2017
# 5             df_tvaas_composite_school_2022
# 6             df_tvaas_composite_school_2021
# 7             df_tvaas_composite_school_2019
# 8             df_tvaas_composite_school_2018
# 9             df_tvaas_composite_school_2017
# 10                    df_profile_school_2021
# 11                    df_profile_school_2020
# 12                    df_profile_school_2019
# 13                    df_profile_school_2018
# 14                    df_profile_school_2017
# 15                    df_profile_school_2016
# 16                    df_profile_school_2015
# 17                    df_profile_school_2014
# 18                    df_profile_school_2013
# 19                    df_profile_school_2012
# 20                    df_profile_school_2011
# 21                    df_profile_school_2010
# 22                  df_profile_district_2021
# 23                  df_profile_district_2020
# 24                  df_profile_district_2019
# 25                  df_profile_district_2018
# 26                  df_profile_district_2013
# 27                  df_profile_district_2012
# 28                  df_profile_district_2011
# 29                  df_profile_district_2010
# 30  df_merged_tvaas_composite_subject_school
# 31          df_merged_tvaas_composite_school
# 32                         df_merged_profile
# 33      df_merged_chronic_absenteeism_school
# 34                   df_merged_census_school
# 35                      df_merged_assessment
# 36                      df_merged_act_school
# 37                  df_directory_school_2022
# 38        df_chronic_absenteeism_school_2022
# 39        df_chronic_absenteeism_school_2021
# 40        df_chronic_absenteeism_school_2020
# 41        df_chronic_absenteeism_school_2019
# 42        df_chronic_absenteeism_school_2018
# 43        df_chronic_absenteeism_school_2017
# 44                     df_census_school_2021
# 45                     df_census_school_2020
# 46                     df_census_school_2019
# 47                     df_census_school_2018
# 48                     df_census_school_2017
# 49                     df_census_school_2016
# 50                     df_census_school_2015
# 51                     df_census_school_2014
# 52                     df_census_school_2013
# 53                  df_assessment_state_2022
# 54                  df_assessment_state_2021
# 55                  df_assessment_state_2019
# 56                  df_assessment_state_2018
# 57                  df_assessment_state_2017
# 58                 df_assessment_school_2022
# 59                 df_assessment_school_2021
# 60                 df_assessment_school_2019
# 61                 df_assessment_school_2018
# 62                 df_assessment_school_2017
# 63                 df_assessment_school_2016
# 64                 df_assessment_school_2015
# 65                 df_assessment_school_2014
# 66                        df_act_school_2021
# 67                        df_act_school_2020
# 68                        df_act_school_2019
# 69                        df_act_school_2018
# 70                        df_act_school_2017
#
#                               prev_file_name  current_num_cols  prev_num_cols  \
# 0     df_tvaas_composite_subject_school_2021                13             15
# 1     df_tvaas_composite_subject_school_2019                15             13
# 2     df_tvaas_composite_subject_school_2018                13             13
# 3     df_tvaas_composite_subject_school_2017                13             13
# 4             df_tvaas_composite_school_2022                13             10
# 5             df_tvaas_composite_school_2021                10              8
# 6             df_tvaas_composite_school_2019                 8              9
# 7             df_tvaas_composite_school_2018                 9             10
# 8             df_tvaas_composite_school_2017                10             10
# 9                     df_profile_school_2021                10             22
# 10                    df_profile_school_2020                22             42
# 11                    df_profile_school_2019                42             43
# 12                    df_profile_school_2018                43             43
# 13                    df_profile_school_2017                43             44
# 14                    df_profile_school_2016                44             44
# 15                    df_profile_school_2015                44             44
# 16                    df_profile_school_2014                44             43
# 17                    df_profile_school_2013                43             46
# 18                    df_profile_school_2012                46             40
# 19                    df_profile_school_2011                40             40
# 20                    df_profile_school_2010                40             40
# 21                  df_profile_district_2021                40             20
# 22                  df_profile_district_2020                20             43
# 23                  df_profile_district_2019                43             48
# 24                  df_profile_district_2018                48             52
# 25                  df_profile_district_2013                52             54
# 26                  df_profile_district_2012                54             55
# 27                  df_profile_district_2011                55             55
# 28                  df_profile_district_2010                55             55
# 29  df_merged_tvaas_composite_subject_school                55             18
# 30          df_merged_tvaas_composite_school                18             13
# 31                         df_merged_profile                13             21
# 32      df_merged_chronic_absenteeism_school                21             14
# 33                   df_merged_census_school                14             15
# 34                      df_merged_assessment                15             21
# 35                      df_merged_act_school                21             19
# 36                  df_directory_school_2022                19             24
# 37        df_chronic_absenteeism_school_2022                24              9
# 38        df_chronic_absenteeism_school_2021                 9              9
# 39        df_chronic_absenteeism_school_2020                 9              9
# 40        df_chronic_absenteeism_school_2019                 9              9
# 41        df_chronic_absenteeism_school_2018                 9             10
# 42        df_chronic_absenteeism_school_2017                10             13
# 43                     df_census_school_2021                13             22
# 44                     df_census_school_2020                22              8
# 45                     df_census_school_2019                 8              8
# 46                     df_census_school_2018                 8              8
# 47                     df_census_school_2017                 8              8
# 48                     df_census_school_2016                 8              8
# 49                     df_census_school_2015                 8              8
# 50                     df_census_school_2014                 8              8
# 51                     df_census_school_2013                 8              8
# 52                  df_assessment_state_2022                 8             20
# 53                  df_assessment_state_2021                20             20
# 54                  df_assessment_state_2019                20             19
# 55                  df_assessment_state_2018                19             17
# 56                  df_assessment_state_2017                17             16
# 57                 df_assessment_school_2022                16             22
# 58                 df_assessment_school_2021                22             22
# 59                 df_assessment_school_2019                22             21
# 60                 df_assessment_school_2018                21             19
# 61                 df_assessment_school_2017                19             16
# 62                 df_assessment_school_2016                16             18
# 63                 df_assessment_school_2015                18             19
# 64                 df_assessment_school_2014                19             19
# 65                        df_act_school_2021                19             16
# 66                        df_act_school_2020                16             16
# 67                        df_act_school_2019                16             16
# 68                        df_act_school_2018                16             16
# 69                        df_act_school_2017                16             14
# 70                                        NA                14              0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       current_cols  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ['district', 'district_number', 'grade', 'growth_measure', 'index', 'level', 'number_of_students', 'school', 'school_number', 'standard_error', 'subject', 'test', 'year']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ['district', 'district_number', 'grade', 'growth_measure', 'index', 'level', 'number_of_students', 'phi_folder', 'rr_folder', 'school', 'school_number', 'standard_error', 'subject', 'test', 'year']
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ['district', 'district_number', 'grade', 'growth_measure', 'index', 'level', 'number_of_students', 'school', 'school_number', 'standard_error', 'subject', 'test', 'year']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ['district', 'district_number', 'grade', 'growth_measure', 'index', 'level', 'number_of_students', 'school', 'school_number', 'standard_error', 'subject', 'test', 'year']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ['district', 'district_number', 'grade', 'growth_measure', 'index', 'level', 'number_of_students', 'school', 'school_number', 'standard_error', 'subject', 'test', 'year']
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['district_name', 'district_number', 'literacy_and_numeracy_composite', 'literacy_composite', 'numeracy_composite', 'overall_composite', 'school_name', 'school_number', 'science_composite', 'social_studies_composite']
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ['district_name', 'district_number', 'literacy_and_numeracy_composite', 'literacy_composite', 'numeracy_composite', 'overall_composite', 'school_name', 'school_number']
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ['district_name', 'district_number', 'literacy_and_numeracy_composite', 'literacy_composite', 'numeracy_composite', 'overall_composite', 'school_name', 'school_number', 'social_studies_composite']
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['district_name', 'district_number', 'literacy_and_numeracy_composite', 'literacy_composite', 'numeracy_composite', 'overall_composite', 'school_name', 'school_number', 'science_composite', 'social_studies_composite']
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['district_name', 'district_number', 'literacy_and_numeracy_composite', 'literacy_composite', 'numeracy_composite', 'overall_composite', 'school_name', 'school_number', 'science_composite', 'social_studies_composite']
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['african_american_pct', 'asian_pct', 'black_hispanic_native_american_pct', 'district_id', 'district_name', 'economically_disadvantaged_pct', 'female_pct', 'foster_pct', 'hawaiian_pacisld_pct', 'hispanic_pct', 'homeless_pct', 'limited_english_proficient_pct', 'male_pct', 'migrant_pct', 'military_pct', 'multirace_pct', 'native_american_pct', 'school_id', 'school_name', 'students_with_disabilities_pct', 'total', 'white_pct']
# 11                                                                                                                                                                                                                                                                                                            ['african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'district_id', 'district_name', 'economically_disadvantaged', 'economically_disadvantaged_pct', 'female', 'female_pct', 'grades_served', 'hawaiian_pacisld', 'hawaiian_pacisld_female', 'hawaiian_pacisld_male', 'hawaiian_pacisld_pct', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'safe_school', 'school_id', 'school_name', 'school_year', 'students_with_disabilities', 'students_with_disabilities_pct', 'total', 'white', 'white_female', 'white_male', 'white_pct']
# 12                                                                                                                                                                                                                                                                                ['african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'average_daily_membership', 'district_id', 'district_name', 'economically_disadvantaged', 'economically_disadvantaged_pct', 'female', 'female_pct', 'grades_served', 'hawaiian_pacisld', 'hawaiian_pacisld_female', 'hawaiian_pacisld_male', 'hawaiian_pacisld_pct', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'safe_school', 'school_id', 'school_name', 'school_year', 'students_with_disabilities', 'students_with_disabilities_pct', 'total', 'white', 'white_female', 'white_male', 'white_pct']
# 13                                                                                                                                                                                                                                                                                ['african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'average_daily_membership', 'district_id', 'district_name', 'economically_disadvantaged', 'economically_disadvantaged_pct', 'female', 'female_pct', 'grades_served', 'hawaiian_pacisld', 'hawaiian_pacisld_female', 'hawaiian_pacisld_male', 'hawaiian_pacisld_pct', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'safe_school', 'school_id', 'school_name', 'school_year', 'students_with_disabilities', 'students_with_disabilities_pct', 'total', 'white', 'white_female', 'white_male', 'white_pct']
# 14                                                                                                                                                                                                                                       ['african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'average_daily_membership', 'district_id', 'district_name', 'economically_disadvantaged', 'economically_disadvantaged_pct', 'female', 'female_pct', 'grades_served', 'hawaiian_pacisld', 'hawaiian_pacisld_female', 'hawaiian_pacisld_male', 'hawaiian_pacisld_pct', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'number_exempt_from_reading_assessment', 'safe_school', 'school_id', 'school_name', 'school_year', 'students_with_disabilities', 'students_with_disabilities_pct', 'total', 'white', 'white_female', 'white_male', 'white_pct']
# 15                                                                                                                                                                                                                                                 ['african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'average_daily_membership', 'district', 'district_name', 'economically_disadvantaged', 'economically_disadvantaged_pct', 'female', 'female_pct', 'grades_served', 'hawaiian_pacisld', 'hawaiian_pacisld_female', 'hawaiian_pacisld_male', 'hawaiian_pacisld_pct', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'number_exempt_from_reading_assessment', 'safe_school', 'school_id', 'school_name', 'students_with_disabilities', 'students_with_disabilities_pct', 'total', 'white', 'white_female', 'white_male', 'white_pct', 'year']
# 16                                                                                                                                                                                                                                                 ['african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'average_daily_membership', 'district', 'district_name', 'economically_disadvantaged', 'economically_disadvantaged_pct', 'female', 'female_pct', 'grades_served', 'hawaiian_pacisld', 'hawaiian_pacisld_female', 'hawaiian_pacisld_male', 'hawaiian_pacisld_pct', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'number_exempt_from_reading_assessment', 'safe_school', 'school_id', 'school_name', 'students_with_disabilities', 'students_with_disabilities_pct', 'total', 'white', 'white_female', 'white_male', 'white_pct', 'year']
# 17                                                                                                                                                                                                                                                                                                                                             ['african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'average_daily_membership', 'district', 'district_name', 'female', 'female_pct', 'free_eligible', 'free_pct', 'free_reduced_eligible', 'free_reduced_pct', 'grades_served', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'reduced_eligible', 'reduced_pct', 'safe_school', 'school_id', 'school_name', 'students_with_disabilities', 'students_with_disabilities_pct', 'total', 'white', 'white_female', 'white_male', 'white_pct', 'year']
# 18                                                                                                                                                                                                                                                                          ['african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'average_daily_membership', 'district', 'district_name', 'female', 'female_pct', 'free_eligible', 'free_pct', 'free_reduced_eligible', 'free_reduced_pct', 'grades_served', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'number_exempt_from_reading_assessment', 'reduced_eligible', 'reduced_pct', 'safe_school', 'school_name', 'school_no', 'students_with_disabilities', 'students_with_disabilities_pct', 'title_i', 'title_i_pct', 'total', 'white', 'white_female', 'white_male', 'white_pct', 'year']
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                           ['african_american', 'african_american_(%)', 'african_american_female', 'african_american_male', 'asian', 'asian_(%)', 'asian_female', 'asian_male', 'average_daily_membership', 'district', 'district_name', 'economically_disadvantaged', 'female', 'female_(%)', 'free_(%)', 'free_eligible', 'free_reduced_(%)', 'free_reduced_eligible', 'grades_served', 'hispanic', 'hispanic_(%)', 'hispanic_female', 'hispanic_male', 'male', 'male_(%)', 'native_american', 'native_american_(%)', 'native_american_female', 'native_american_male', 'reduced_(%)', 'reduced_eligible', 'safe_school_status', 'school', 'school_name', 'total', 'white', 'white_(%)', 'white_female', 'white_male', 'year']
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                           ['african_american', 'african_american_(%)', 'african_american_female', 'african_american_male', 'asian', 'asian_(%)', 'asian_female', 'asian_male', 'average_daily_membership', 'district', 'district_name', 'economically_disadvantaged', 'female', 'female_(%)', 'free_(%)', 'free_eligible', 'free_reduced_(%)', 'free_reduced_eligible', 'grades_served', 'hispanic', 'hispanic_(%)', 'hispanic_female', 'hispanic_male', 'male', 'male_(%)', 'native_american', 'native_american_(%)', 'native_american_female', 'native_american_male', 'reduced_(%)', 'reduced_eligible', 'safe_school_status', 'school', 'school_name', 'total', 'white', 'white_(%)', 'white_female', 'white_male', 'year']
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                           ['african_american', 'african_american_(%)', 'african_american_female', 'african_american_male', 'asian', 'asian_(%)', 'asian_female', 'asian_male', 'average_daily_membership', 'district', 'district_name', 'economically_disadvantaged', 'female', 'female_(%)', 'free_(%)', 'free_eligible', 'free_reduced_(%)', 'free_reduced_eligible', 'grades_served', 'hispanic', 'hispanic_(%)', 'hispanic_female', 'hispanic_male', 'male', 'male_(%)', 'native_american', 'native_american_(%)', 'native_american_female', 'native_american_male', 'reduced_(%)', 'reduced_eligible', 'safe_school_status', 'school', 'school_name', 'total', 'white', 'white_(%)', 'white_female', 'white_male', 'year']
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ['african_american_pct', 'asian_pct', 'black_hispanic_native_american_pct', 'district_id', 'district_name', 'economically_disadvantaged_pct', 'female_pct', 'foster_pct', 'hawaiian_pacisld_pct', 'hispanic_pct', 'homeless_pct', 'limited_english_proficient_pct', 'male_pct', 'migrant_pct', 'military_pct', 'multirace_pct', 'native_american_pct', 'students_with_disabilities_pct', 'total', 'white_pct']
# 23                                                                                                                                                                                                                                                                                 ['administrators', 'african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'district_id', 'district_name', 'economically_disadvantaged', 'economically_disadvantaged_pct', 'female', 'female_pct', 'grades_served', 'hawaiian_pacisld', 'hawaiian_pacisld_female', 'hawaiian_pacisld_male', 'hawaiian_pacisld_pct', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'number_of_schools', 'school_year', 'students_with_disabilities', 'students_with_disabilities_pct', 'teachers', 'total', 'total_educators', 'white', 'white_female', 'white_male', 'white_pct']
# 24                                                                                                                                                  ['administrators', 'african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'average_daily_membership', 'district_id', 'district_name', 'economically_disadvantaged', 'economically_disadvantaged_pct', 'federal_funding_pct', 'female', 'female_pct', 'grades_served', 'hawaiian_pacisld', 'hawaiian_pacisld_female', 'hawaiian_pacisld_male', 'hawaiian_pacisld_pct', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'local_funding_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'number_of_schools', 'per_pupil_expenditures_per_ada', 'school_year', 'state_funding_pct', 'students_with_disabilities', 'students_with_disabilities_pct', 'teachers', 'total', 'total_educators', 'white', 'white_female', 'white_male', 'white_pct']
# 25                                  ['administrators', 'african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'average_daily_membership', 'district', 'district_name', 'economically_disadvantaged', 'economically_disadvantaged_pct', 'federal_funding_pct', 'female', 'female_pct', 'grades_served', 'hawaiian_pacisld', 'hawaiian_pacisld_female', 'hawaiian_pacisld_male', 'hawaiian_pacisld_pct', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'local_funding_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'number_of_schools', 'per_pupil_expenditures_per_ada', 'school_year', 'state_federal_funding_pct', 'state_funding_pct', 'state_local_funding_pct', 'state_per_pupil_expenditures', 'state_state_funding_pct', 'students_with_disabilities', 'students_with_disabilities_pct', 'teachers', 'total', 'total_educators', 'white', 'white_female', 'white_male', 'white_pct']
# 26                                    ['administrators', 'african_american', 'african_american_female', 'african_american_male', 'african_american_pct', 'asian', 'asian_female', 'asian_male', 'asian_pct', 'average_daily_membership', 'district', 'district_name', 'federal_funding_pct', 'female', 'female_pct', 'free_eligible', 'free_pct', 'free_reduced_eligible', 'free_reduced_pct', 'grades_served', 'hispanic', 'hispanic_female', 'hispanic_male', 'hispanic_pct', 'limited_english_proficient', 'limited_english_proficient_pct', 'local_funding_pct', 'male', 'male_pct', 'native_american', 'native_american_female', 'native_american_male', 'native_american_pct', 'number_exempt_from_reading_assessment', 'number_of_schools', 'per_pupil_expenditures_per_ada', 'reduced_eligible', 'reduced_pct', 'state_federal_funding_pct', 'state_funding_pct', 'state_local_funding_pct', 'state_per_pupil_expenditures_per_ada', 'state_state_funding_pct', 'students_with_disabilities', 'students_with_disabilities_pct', 'teachers', 'title_i', 'title_i_pct', 'total', 'white', 'white_female', 'white_male', 'white_pct', 'year']
# 27  ['administrators', 'african_american', 'african_american_(%)', 'african_american_female', 'african_american_male', 'asian', 'asian_(%)', 'asian_female', 'asian_male', 'average_daily_membership', 'district', 'district_name', 'economically_disadvantaged', 'federal_funding_(%)', 'female', 'female_(%)', 'free_(%)', 'free_eligible', 'free_reduced_(%)', 'free_reduced_eligible', 'grades_served', 'hispanic', 'hispanic_(%)', 'hispanic_female', 'hispanic_male', 'limited_english_proficient', 'limited_english_proficient_(%)', 'local_funding_(%)', 'male', 'male_(%)', 'native_american', 'native_american_(%)', 'native_american_female', 'native_american_male', 'number_exempt_from_reading_assessment', 'number_of_schools', 'per_pupil_expenditures_per_ada', 'reduced_(%)', 'reduced_eligible', 'state:_federal_funding_(%)', 'state:_local_funding_(%)', 'state:_per_pupil_expenditures_per_ada', 'state:_state_funding_(%)', 'state_funding_(%)', 'students_with_disabilities', 'students_with_disabilities_(%)', 'teachers', 'title_i', 'title_i_(%)', 'total', 'white', 'white_(%)', 'white_female', 'white_male', 'year']
# 28  ['administrators', 'african_american', 'african_american_(%)', 'african_american_female', 'african_american_male', 'asian', 'asian_(%)', 'asian_female', 'asian_male', 'average_daily_membership', 'district', 'district_name', 'economically_disadvantaged', 'federal_funding_(%)', 'female', 'female_(%)', 'free_(%)', 'free_eligible', 'free_reduced_(%)', 'free_reduced_eligible', 'grades_served', 'hispanic', 'hispanic_(%)', 'hispanic_female', 'hispanic_male', 'limited_english_proficient', 'limited_english_proficient_(%)', 'local_funding_(%)', 'male', 'male_(%)', 'native_american', 'native_american_(%)', 'native_american_female', 'native_american_male', 'number_exempt_from_reading_assessment', 'number_of_schools', 'per_pupil_expenditures_per_ada', 'reduced_(%)', 'reduced_eligible', 'state:_federal_funding_(%)', 'state:_local_funding_(%)', 'state:_per_pupil_expenditures_per_ada', 'state:_state_funding_(%)', 'state_funding_(%)', 'students_with_disabilities', 'students_with_disabilities_(%)', 'teachers', 'title_i', 'title_i_(%)', 'total', 'white', 'white_(%)', 'white_female', 'white_male', 'year']
# 29  ['administrators', 'african_american', 'african_american_(%)', 'african_american_female', 'african_american_male', 'asian', 'asian_(%)', 'asian_female', 'asian_male', 'average_daily_membership', 'district', 'district_name', 'economically_disadvantaged', 'federal_funding_(%)', 'female', 'female_(%)', 'free_(%)', 'free_eligible', 'free_reduced_(%)', 'free_reduced_eligible', 'grades_served', 'hispanic', 'hispanic_(%)', 'hispanic_female', 'hispanic_male', 'limited_english_proficient', 'limited_english_proficient_(%)', 'local_funding_(%)', 'male', 'male_(%)', 'native_american', 'native_american_(%)', 'native_american_female', 'native_american_male', 'number_exempt_from_reading_assessment', 'number_of_schools', 'per_pupil_expenditures_per_ada', 'reduced_(%)', 'reduced_eligible', 'state:_federal_funding_(%)', 'state:_local_funding_(%)', 'state:_per_pupil_expenditures_per_ada', 'state:_state_funding_(%)', 'state_funding_(%)', 'students_with_disabilities', 'students_with_disabilities_(%)', 'teachers', 'title_i', 'title_i_(%)', 'total', 'white', 'white_(%)', 'white_female', 'white_male', 'year']
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['district', 'district_number', 'file_source', 'file_year', 'grade', 'growth_measure', 'index', 'level', 'number_of_students', 'school', 'school_number', 'school_type', 'standard_error', 'status', 'subject', 'test', 'updated_district_number', 'year']
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['district_name', 'district_number', 'file_source', 'file_year', 'literacy_and_numeracy_composite', 'literacy_composite', 'numeracy_composite', 'overall_composite', 'school_name', 'school_number', 'school_type', 'status', 'updated_district_number']
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ['african_american_pct', 'asian_pct', 'district_name', 'district_number', 'economically_disadvantaged_pct', 'female_pct', 'file_source', 'file_year', 'hawaiian_pacisld_pct', 'hispanic_pct', 'limited_english_proficient_pct', 'male_pct', 'native_american_pct', 'school_name', 'school_number', 'school_type', 'status', 'students_with_disabilities_pct', 'total', 'updated_district_number', 'white_pct']
# ...
# 58                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ['n_exceeded_expectations', 'n_met_expectations', 'pct_exceeded_expectations', 'pct_met_exceeded', 'pct_met_expectations', 'student_group']
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['participation_rate']
# 60                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['enrolled', 'tested']
# 61                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['school_name', 'system_name', 'test']
# 62                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['n_approaching', 'n_below', 'n_mastered', 'n_on_track', 'pct_approaching', 'pct_below', 'pct_mastered', 'pct_on_mastered', 'pct_on_track', 'system', 'valid_tests']
# 63                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['#_approaching_(prev._basic)', '#_below_(prev._below_basic)', '#_mastered_(prev._advanced)', '#_on_track_(prev._proficient)', '#_valid_tests', '%_approaching_(prev._basic)', '%_below_(prev._below_basic)', '%_mastered_(prev._advanced)', '%_on_track_(prev._proficient)', '%_on_track_or_mastered_(prev._%_proficient/advanced)', 'district', 'district_name']
# 64                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          []
# 65                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ['grade', 'n_adv', 'n_below_bsc', 'n_bsc', 'n_prof', 'pct_adv', 'pct_below_bsc', 'pct_bsc', 'pct_bsc_and_below', 'pct_prof', 'pct_prof_adv', 'subject', 'system', 'system_name', 'year']
# 66                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          []
# 67                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          []
# 68                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          []
# 69                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ['number_scoring_21_or_higher', 'number_scoring_below_19']
# 70                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ['average_composite_score', 'average_english_score', 'average_math_score', 'average_reading_score', 'average_science_score', 'district', 'district_name', 'participation_rate', 'percent_scoring_21_or_higher', 'percent_scoring_below_19', 'school', 'school_name', 'subgroup', 'valid_tests']
#
#     num_mismatching
# 0                 0
# 1                 2
# 2                 0
# 3                 0
# 4                11
# 5                 2
# 6                 0
# 7                 0
# 8                 0
# 9                 8
# 10                6
# 11                0
# 12                0
# 13                0
# 14                2
# 15                0
# 16                7
# 17                1
# 18               19
# 19                0
# 20                0
# 21               38
# 22                6
# 23                0
# 24                1
# 25                9
# 26               20
# 27                0
# 28                0
# 29               53
# 30               11
# 31                4
# 32               12
# 33                5
# 34                6
# 35               11
# 36               19
# 37               24
# 38                1
# 39                0
# 40                0
# 41                6
# 42                7
# 43               12
# 44               20
# 45                0
# 46                1
# 47                3
# 48                1
# 49                0
# 50                0
# 51                1
# 52                7
# 53                6
# 54                1
# 55                2
# 56                1
# 57                6
# 58                6
# 59                1
# 60                2
# 61                3
# 62               11
# 63               12
# 64                0
# 65               15
# 66                0
# 67                0
# 68                0
# 69                2
# 70               14

# %%
df_directory_school_2022 = df_directory_school_2022[['_district_no','_district','_school_no','_school','_school_type'
                                                     ,'_address', '_city', '_state','_zipcode','_nces_school_number','_status'
                                                     ]]
df_directory_school_2022.columns = ['district_number','district_name','school_number', 'school_name', 'school_type'
                                   ,'address', 'city', 'state','zip','nces_school_number','status']
# df_directory_school_2022['updated_district_number'] = df_directory_school_2022['district_number'].copy()
# need to change to MNPS : 8020, 8015, 8090, 8005

# %%
## Manually changing some of the charters authorized outside of MNPS but within Nashville
df_directory_school_2022['updated_district_number'] = (
    np.where((df_directory_school_2022['school_number']==8020) & (df_directory_school_2022['district_number']==986) | # Changed to 987: KIPP Antioch College Prep Middle
             (df_directory_school_2022['school_number']==8015) & (df_directory_school_2022['district_number']==986) | # Changed to 987: KIPP Antioch College Prep Elementary
             (df_directory_school_2022['school_number']==8030) & (df_directory_school_2022['district_number']==987) | # Nashville Collegiate Prep
             (df_directory_school_2022['school_number']==8020) & (df_directory_school_2022['district_number']==987) | # KIPP Antioch College Prep Middle
             (df_directory_school_2022['school_number']==8015) & (df_directory_school_2022['district_number']==987) | # KIPP Antioch College Prep Elementary
             (df_directory_school_2022['school_number']==8090) & (df_directory_school_2022['district_number']==985) | # Neely's Bend: A LEAD Public School
             (df_directory_school_2022['school_number']==8145) & (df_directory_school_2022['district_number']==985) | # Inactive: Rocketship Partners Community Prep
             (df_directory_school_2022['school_number']==8005) & (df_directory_school_2022['district_number']==985),  # Brick Church: A LEAD Public School
             190,
             df_directory_school_2022['district_number'])
)

# %%
charter_school_list = df_directory_school_2022.loc[(df_directory_school_2022['school_type']=='Public Charter') & (df_directory_school_2022['updated_district_number']==190)]

# %%
charter_school_list.to_csv('../data_for_analysis/charter_school_list.csv')

# %%
c = ['district', 'district_number', 'grade', 'growth_measure', 'index', 'level', 'number_of_students', 'school', 'school_number', 'standard_error', 'subject', 'test', 'year']
df_to_change_and_merge('df_tvaas_composite_subject_school',c)
df_tvaas_composite_subject_school.head()
# Out:
#           district  district_number grade growth_measure index    level  \
# 0  Anderson County               10   3.0           -2.2 -0.59  Level 3
# 1  Anderson County               10   4.0           11.4  3.72  Level 5
# 2  Anderson County               10   5.0           -9.6 -3.16  Level 1
# 3  Anderson County               10   3.0           -8.1 -1.73  Level 2
# 4  Anderson County               10   4.0            2.3  0.82  Level 3
#
#    number_of_students                 school  school_number standard_error  \
# 0                  23  Briceville Elementary             10            3.6
# 1                  17  Briceville Elementary             10            3.1
# 2                  17  Briceville Elementary             10            3.0
# 3                  22  Briceville Elementary             10            4.7
# 4                  16  Briceville Elementary             10            2.8
#
#                  subject        test  year  \
# 0  English Language Arts  Grades 3-8  2022
# 1  English Language Arts  Grades 3-8  2022
# 2  English Language Arts  Grades 3-8  2022
# 3                   Math  Grades 3-8  2022
# 4                   Math  Grades 3-8  2022
#
#                               file_source file_year  updated_district_number  \
# 0  df_tvaas_composite_subject_school_2022      2022                       10
# 1  df_tvaas_composite_subject_school_2022      2022                       10
# 2  df_tvaas_composite_subject_school_2022      2022                       10
# 3  df_tvaas_composite_subject_school_2022      2022                       10
# 4  df_tvaas_composite_subject_school_2022      2022                       10
#
#   school_type status
# 0      Public      A
# 1      Public      A
# 2      Public      A
# 3      Public      A
# 4      Public      A

# %%
c = ['district_name', 'district_number', 'literacy_and_numeracy_composite', 'literacy_composite', 'numeracy_composite', 'overall_composite', 'school_name', 'school_number']
df_to_change_and_merge('df_tvaas_composite_school',c)
# df_tvaas_composite_school.head()

# %%
df_chronic_absenteeism_school_2022.columns
# Out:
# Index(['system', 'system_name', 'school', 'school_name', 'student_group',
#        'grade_band', 'n_students', 'n_chronically_absent',
#        'pct_chronically_absent'],
#       dtype='object')

# %%
df_chronic_absenteeism_school_2022 = df_chronic_absenteeism_school_2022.rename(columns={'school':'school_number', 'system':'district_number', 'system_name':'district_name'}).copy()
df_chronic_absenteeism_school_2021 = df_chronic_absenteeism_school_2021.rename(columns={'school':'school_number', 'system':'district_number', 'system_name':'district_name','subgroup':'student_group'}).copy()
df_chronic_absenteeism_school_2020 = df_chronic_absenteeism_school_2020.rename(columns={'school':'school_number', 'system':'district_number', 'system_name':'district_name','subgroup':'student_group'}).copy()
df_chronic_absenteeism_school_2019 = df_chronic_absenteeism_school_2019.rename(columns={'school':'school_number', 'system':'district_number', 'system_name':'district_name','subgroup':'student_group'}).copy()
df_chronic_absenteeism_school_2018 = df_chronic_absenteeism_school_2018.rename(columns={'district':'district_number', 
                                                                                        'system_name':'district_name', 
                                                                                        'school':'school_number',
                                                                                        '#_students':'n_students', 
                                                                                        '#_chronically_absent':'n_chronically_absent',
                                                                                        '%_chronically_absent':'pct_chronically_absent'}).copy()
df_chronic_absenteeism_school_2017['grade_band'] = 'All Grades'
df_chronic_absenteeism_school_2017 = df_chronic_absenteeism_school_2017.rename(columns={'system':'district_number','system_name':'district_name', 'school':'school_number', 'subgroup':'student_group'})
c = ['grade_band', 'n_chronically_absent', 'n_students', 'pct_chronically_absent', 'school_number', 'school_name', 'student_group', 'district_number', 'district_name']
df_to_change_and_merge('df_chronic_absenteeism_school',c)

# %%
df_chronic_absenteeism_school_2022
# Out:
#        grade_band n_chronically_absent  n_students pct_chronically_absent  \
# 0      All Grades                  245        1062                   23.1
# 1      All Grades                    *           6                      *
# 2      All Grades                   **          11                     **
# 3      All Grades                    3          19                   15.8
# 4      All Grades                    6          46                     13
# ...           ...                  ...         ...                    ...
# 17743  All Grades                  245         397                   61.7
# 17744  All Grades                  133         201                   66.2
# 17745  All Grades                    9          28                   32.1
# 17746  All Grades                    6          17                   35.3
# 17747  All Grades                   29          59                   49.2
#
#        school_number                  school_name  \
# 0                  2  Anderson County High School
# 1                  2  Anderson County High School
# 2                  2  Anderson County High School
# 3                  2  Anderson County High School
# 4                  2  Anderson County High School
# ...              ...                          ...
# 17743           8140        Hillcrest High School
# 17744           8140        Hillcrest High School
# 17745           8140        Hillcrest High School
# 17746           8140        Hillcrest High School
# 17747           8140        Hillcrest High School
#
#                                 student_group  district_number  \
# 0                                All Students               10
# 1            American Indian or Alaska Native               10
# 2                                       Asian               10
# 3                   Black or African American               10
# 4              Black/Hispanic/Native American               10
# ...                                       ...              ...
# 17743          Black/Hispanic/Native American              985
# 17744              Economically Disadvantaged              985
# 17745  English Learners with Transitional 1-4              985
# 17746                                Hispanic              985
# 17747              Students with Disabilities              985
#
#                      district_name                         file_source  \
# 0                  Anderson County  df_chronic_absenteeism_school_2022
# 1                  Anderson County  df_chronic_absenteeism_school_2022
# 2                  Anderson County  df_chronic_absenteeism_school_2022
# 3                  Anderson County  df_chronic_absenteeism_school_2022
# 4                  Anderson County  df_chronic_absenteeism_school_2022
# ...                            ...                                 ...
# 17743  Achievement School District  df_chronic_absenteeism_school_2022
# 17744  Achievement School District  df_chronic_absenteeism_school_2022
# 17745  Achievement School District  df_chronic_absenteeism_school_2022
# 17746  Achievement School District  df_chronic_absenteeism_school_2022
# 17747  Achievement School District  df_chronic_absenteeism_school_2022
#
#       file_year
# 0          2022
# 1          2022
# 2          2022
# 3          2022
# 4          2022
# ...         ...
# 17743      2022
# 17744      2022
# 17745      2022
# 17746      2022
# 17747      2022
#
# [17748 rows x 11 columns]

# %%
df_census_school_2021 = df_census_school_2021[['district_id','district_name','school_id','school_name','total','asian_pct','african_american_pct','hispanic_pct','hawaiian_pacisld_pct','white_pct']].rename(columns={'district_id':'district_number','school_id':'school_number'}).copy()
df_census_school_2020 = df_census_school_2020.rename(columns={'race':'race_or_ethnicity','district':'district_number','school':'school_number'}).copy()
df_census_school_2019 = df_census_school_2019.rename(columns={'race':'race_or_ethnicity','district':'district_number','school':'school_number'}).copy()
df_census_school_2018 = df_census_school_2018.rename(columns={'race':'race_or_ethnicity','district':'district_number','school':'school_number', 'grade_':'grade'}).copy()
df_census_school_2017 = df_census_school_2017.rename(columns={'race':'race_or_ethnicity','district_id':'district_number','school_id':'school_number'}).copy()
df_census_school_2016 = df_census_school_2016.rename(columns={'district_id':'district_number','school_id':'school_number'}).copy()
df_census_school_2015 = df_census_school_2015.rename(columns={'district_id':'district_number','school_id':'school_number'}).copy()
df_census_school_2014 = df_census_school_2014.rename(columns={'district_id':'district_number','school_id':'school_number'}).copy()
df_census_school_2013 = df_census_school_2013.rename(columns={'district_id':'district_number','school_id':'school_number','schoolname':'school_name'}).copy()

df_census_filter_gender_grades = ['df_census_school_2020', 'df_census_school_2019', 'df_census_school_2018', 'df_census_school_2016']
df_census_filter_gender = ['df_census_school_2017','df_census_school_2015', 'df_census_school_2014', 'df_census_school_2013']

for c in df_census_filter_gender_grades:
    df_pivot = (globals()[c][(globals()[c]['grade']=='All Grades') & ((globals()[c]['gender']=='All Genders')|(globals()[c]['gender']=='M & F'))].pivot(index=['district_number','district_name','school_number','school_name'], columns=['race_or_ethnicity'], values='enrollment').reset_index()).copy()

    df_pivot = df_pivot.rename(columns={'All Race/Ethnic Groups':'total',
                                        'Asian':'asian',
                                        'Black or African American':'african_american',
                                        'Hispanic':'hispanic',
                                        'Hispanic or Latino ethnicity':'hispanic',
                                        'Native Hawaiian or Pacific Islander':'hawaiian_pacisld',
                                        'Native Hawaiian or Other Pacific Islander':'hawaiian_pacisld',
                                        'White':'white'})

    df_pivot['asian_pct'] = (df_pivot['asian'])/(df_pivot['total']) * 100
    df_pivot['african_american_pct'] = (df_pivot['african_american'])/(df_pivot['total']) * 100
    df_pivot['hispanic_pct'] = (df_pivot['hispanic'])/(df_pivot['total']) * 100
    df_pivot['hawaiian_pacisld_pct'] = (df_pivot['hawaiian_pacisld'])/(df_pivot['total']) * 100
    df_pivot['white_pct'] = (df_pivot['white'])/(df_pivot['total']) * 100
    globals()[c] = df_pivot[['district_number','district_name','school_number','school_name','total','asian_pct','african_american_pct','hispanic_pct','hawaiian_pacisld_pct','white_pct']].copy()

for c in df_census_filter_gender:
    df_pivot = globals()[c][(globals()[c]['grade']!='All Grades') & ((globals()[c]['gender']=='All Genders')|(globals()[c]['gender']=='M & F'))].groupby(['district_number','district_name','school_number','school_name','race_or_ethnicity'])[['enrollment']].sum().reset_index()
    df_pivot = (df_pivot.pivot(index=['district_number','district_name','school_number','school_name'], columns=['race_or_ethnicity'], values='enrollment').reset_index()).copy()
    
    df_pivot = df_pivot.rename(columns={'All Race/Ethnic Groups':'total',
                                        'Asian':'asian',
                                        'Black or African American':'african_american',
                                        'Hispanic':'hispanic',
                                        'Hispanic or Latino ethnicity':'hispanic',
                                        'Hispanic/Latino':'hispanic',
                                        'Native Hawaiian or Pacific Islander':'hawaiian_pacisld',
                                        'Native Hawaiian or Other Pacific Islander':'hawaiian_pacisld',
                                        'White':'white'})

    df_pivot['asian_pct'] = (df_pivot['asian'])/(df_pivot['total']) * 100
    df_pivot['african_american_pct'] = (df_pivot['african_american'])/(df_pivot['total']) * 100
    df_pivot['hispanic_pct'] = (df_pivot['hispanic'])/(df_pivot['total']) * 100
    df_pivot['hawaiian_pacisld_pct'] = (df_pivot['hawaiian_pacisld'])/(df_pivot['total']) * 100
    df_pivot['white_pct'] = (df_pivot['white'])/(df_pivot['total']) * 100
    globals()[c] = df_pivot[['district_number','district_name','school_number','school_name','total','asian_pct','african_american_pct','hispanic_pct','hawaiian_pacisld_pct','white_pct']].copy()

# %%
c = ['district_number','district_name','school_number','school_name','total','asian_pct','african_american_pct','hispanic_pct','hawaiian_pacisld_pct','white_pct']
df_to_change_and_merge('df_census_school',c)

# %%
df_census_school[['file_year','african_american_pct']].drop_duplicates()
# Out:
#       file_year african_american_pct
# 0          2021         Less than 5%
# 2          2021                    *
# 5          2021                    6
# 8          2021                  5.6
# 13         2021                  7.8
# ...         ...                  ...
# 15967      2013            94.117647
# 15968      2013            96.648045
# 15969      2013            83.495146
# 15970      2013            96.507937
# 15971      2013            95.205479
#
# [13434 rows x 2 columns]

# %%
df_assessment_school_2019['enrolled'] = np.NaN
df_assessment_school_2018['enrolled'] = np.NaN
df_assessment_school_2017['enrolled'] = np.NaN
df_assessment_school_2016['enrolled'] = np.NaN
df_assessment_school_2015['enrolled'] = np.NaN
df_assessment_school_2014['enrolled'] = np.NaN
df_assessment_school_2017['test'] = np.NaN
df_assessment_school_2016['test'] = np.NaN
df_assessment_school_2015['test'] = np.NaN
df_assessment_school_2014['test'] = np.NaN
df_assessment_school_2017['system_name'] = np.NaN
df_assessment_school_2017['school_name'] = np.NaN
df_assessment_school_2022 = df_assessment_school_2022.rename(columns={'system':'district_number',
                                                                      'system_name':'district_name',
                                                                      'school':'school_number'}).copy()
df_assessment_school_2021 = df_assessment_school_2021.rename(columns={'system':'district_number',
                                                                      'system_name':'district_name',
                                                                      'school':'school_number',
                                                                      'subgroup':'student_group',
                                                                      'pct_on_track':'pct_met_expectations',
                                                                      'pct_mastered':'pct_exceeded_expectations',
                                                                      'pct_on_mastered':'pct_met_exceeded'}).copy()
df_assessment_school_2019 = df_assessment_school_2019.rename(columns={'system':'district_number','system_name':'district_name','school':'school_number','subgroup':'student_group','pct_on_track':'pct_met_expectations','pct_mastered':'pct_exceeded_expectations','pct_on_mastered':'pct_met_exceeded'}).copy()
df_assessment_school_2018 = df_assessment_school_2018.rename(columns={'system':'district_number','system_name':'district_name','school':'school_number','subgroup':'student_group','pct_on_track':'pct_met_expectations','pct_mastered':'pct_exceeded_expectations','pct_on_mastered':'pct_met_exceeded'}).copy()
df_assessment_school_2017 = df_assessment_school_2017.rename(columns={'system':'district_number','system_name':'district_name','school':'school_number','subgroup':'student_group','pct_on_track':'pct_met_expectations','pct_mastered':'pct_exceeded_expectations','pct_on_mastered':'pct_met_exceeded'}).copy()
df_assessment_school_2016 = df_assessment_school_2016.rename(columns={'district':'district_number','school':'school_number','#_valid_tests':'valid_tests','subgroup':'student_group',
                                          '%_below_(prev._below_basic)':'pct_below', '%_approaching_(prev._basic)':'pct_approaching', 
                                          '%_on_track_(prev._proficient)':'pct_met_expectations','%_mastered_(prev._advanced)':'pct_exceeded_expectations',
                                          '%_on_track_or_mastered_(prev._%_proficient/advanced)':'pct_met_exceeded'}).copy()
df_assessment_school_2015 = df_assessment_school_2015.rename(columns={'system':'district_number','system_name':'district_name','school':'school_number','subgroup':'student_group',
                                          'pct_below_bsc':'pct_below',
                                          'pct_bsc':'pct_approaching', 
                                          'pct_prof':'pct_met_expectations',
                                          'pct_adv':'pct_exceeded_expectations',
                                          'pct_prof_adv':'pct_met_exceeded'}).copy()
df_assessment_school_2014 = df_assessment_school_2014.rename(columns={'system':'district_number','system_name':'district_name','school':'school_number','subgroup':'student_group',
                                          'pct_below_bsc':'pct_below', 
                                          'pct_bsc':'pct_approaching', 
                                          'pct_prof':'pct_met_expectations',
                                          'pct_adv':'pct_exceeded_expectations',
                                          'pct_prof_adv':'pct_met_exceeded'}).copy()
df_assessment_state_2019['enrolled'] = np.NaN
df_assessment_state_2018['enrolled'] = np.NaN
df_assessment_state_2017['enrolled'] = np.NaN
df_assessment_state_2017['test'] = np.NaN
df_assessment_state_2021 = df_assessment_state_2021.rename(columns={'subgroup':'student_group','pct_on_track':'pct_met_expectations','pct_mastered':'pct_exceeded_expectations','pct_on_mastered':'pct_met_exceeded'}).copy()
df_assessment_state_2019 = df_assessment_state_2019.rename(columns={'subgroup':'student_group','pct_on_track':'pct_met_expectations','pct_mastered':'pct_exceeded_expectations','pct_on_mastered':'pct_met_exceeded'}).copy()
df_assessment_state_2018 = df_assessment_state_2018.rename(columns={'subgroup':'student_group','pct_on_track':'pct_met_expectations','pct_mastered':'pct_exceeded_expectations','pct_on_mastered':'pct_met_exceeded'}).copy()
df_assessment_state_2017 = df_assessment_state_2017.rename(columns={'subgroup':'student_group','pct_on_track':'pct_met_expectations','pct_mastered':'pct_exceeded_expectations','pct_on_mastered':'pct_met_exceeded'}).copy()

# %%
state_dfs = [df_assessment_state_2017,
             df_assessment_state_2018, 
             df_assessment_state_2019, 
             df_assessment_state_2021, 
             df_assessment_state_2022]
for d in state_dfs: 
    d['district_number'] = 0
    d['district_name'] = 'State of Tennessee'
    d['school_number'] = 0
    d['school_name'] = 'All Schools'

# %%
c = ['year', 'district_number', 'district_name', 'school_number', 'school_name', 'test',
     'subject', 'grade', 'student_group', 'enrolled', 'valid_tests',
     'pct_below','pct_approaching','pct_met_expectations','pct_exceeded_expectations','pct_met_exceeded']
df_to_change_and_merge('df_assessment',c)
# Out:
# /var/folders/31/7zf4qdcn4rd2jrs56bmr97vh0000gn/T/ipykernel_46335/2795759985.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globals()[d]['file_source'] = d
# /var/folders/31/7zf4qdcn4rd2jrs56bmr97vh0000gn/T/ipykernel_46335/2795759985.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globals()[d]['file_year'] = d.split('_')[-1]
# /var/folders/31/7zf4qdcn4rd2jrs56bmr97vh0000gn/T/ipykernel_46335/2795759985.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globals()[d]['file_source'] = d
# /var/folders/31/7zf4qdcn4rd2jrs56bmr97vh0000gn/T/ipykernel_46335/2795759985.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globals()[d]['file_year'] = d.split('_')[-1]
# /var/folders/31/7zf4qdcn4rd2jrs56bmr97vh0000gn/T/ipykernel_46335/2795759985.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globals()[d]['file_source'] = d
# /var/folders/31/7zf4qdcn4rd2jrs56bmr97vh0000gn/T/ipykernel_46335/2795759985.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globals()[d]['file_year'] = d.split('_')[-1]
# /var/folders/31/7zf4qdcn4rd2jrs56bmr97vh0000gn/T/ipykernel_46335/2795759985.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globals()[d]['file_source'] = d
# /var/folders/31/7zf4qdcn4rd2jrs56bmr97vh0000gn/T/ipykernel_46335/2795759985.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globals()[d]['file_year'] = d.split('_')[-1]
# /var/folders/31/7zf4qdcn4rd2jrs56bmr97vh0000gn/T/ipykernel_46335/2795759985.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globals()[d]['file_source'] = d
# /var/folders/31/7zf4qdcn4rd2jrs56bmr97vh0000gn/T/ipykernel_46335/2795759985.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globals()[d]['file_year'] = d.split('_')[-1]

# %%
df_assessment.loc[(df_assessment['school_number']==8015) & (df_assessment['year']==2022) & (df_assessment['district_number']!=df_assessment['updated_district_number'])]
# Out:
#         year  district_number                               district_name  \
# 685693  2022              987  Tennessee Public Charter School Commission
# 685694  2022              987  Tennessee Public Charter School Commission
# 685695  2022              987  Tennessee Public Charter School Commission
# 685696  2022              987  Tennessee Public Charter School Commission
# 685697  2022              987  Tennessee Public Charter School Commission
# ...      ...              ...                                         ...
# 685796  2022              987  Tennessee Public Charter School Commission
# 685797  2022              987  Tennessee Public Charter School Commission
# 685798  2022              987  Tennessee Public Charter School Commission
# 685799  2022              987  Tennessee Public Charter School Commission
# 685800  2022              987  Tennessee Public Charter School Commission
#
#         school_number                           school_name     test  subject  \
# 685693           8015  KIPP Antioch College Prep Elementary  TNReady      ELA
# 685694           8015  KIPP Antioch College Prep Elementary  TNReady      ELA
# 685695           8015  KIPP Antioch College Prep Elementary  TNReady      ELA
# 685696           8015  KIPP Antioch College Prep Elementary  TNReady      ELA
# 685697           8015  KIPP Antioch College Prep Elementary  TNReady      ELA
# ...               ...                                   ...      ...      ...
# 685796           8015  KIPP Antioch College Prep Elementary  TNReady  Science
# 685797           8015  KIPP Antioch College Prep Elementary  TNReady  Science
# 685798           8015  KIPP Antioch College Prep Elementary  TNReady  Science
# 685799           8015  KIPP Antioch College Prep Elementary  TNReady  Science
# 685800           8015  KIPP Antioch College Prep Elementary  TNReady  Science
#
#              grade                          student_group  enrolled  \
# 685693           3                           All Students     129.0
# 685694           3                                  Asian      20.0
# 685695           3              Black or African American      48.0
# 685696           3         Black/Hispanic/Native American      87.0
# 685697           3             Economically Disadvantaged      34.0
# ...            ...                                    ...       ...
# 685796  All Grades  Non-English Learners/Transitional 1-4      99.0
# 685797  All Grades         Non-Students with Disabilities     116.0
# 685798  All Grades             Students with Disabilities      13.0
# 685799  All Grades                         Super Subgroup     111.0
# 685800  All Grades                                  White      22.0
#
#         valid_tests pct_below pct_approaching pct_met_expectations  \
# 685693        129.0      15.4            41.9                 31.8
# 685694         20.0        15              35                   35
# 685695         48.0      12.4            41.7                 31.3
# 685696         87.0      13.8            43.7                 33.3
# 685697         34.0      14.8            52.9                 23.5
# ...             ...       ...             ...                  ...
# 685796         99.0      13.1            39.4                 42.4
# 685797        116.0      11.2            42.2                 39.7
# 685798         13.0        **              **                   **
# 685799        111.0      12.7            44.1                 37.8
# 685800         22.0       9.1              50                 31.8
#
#        pct_exceeded_expectations pct_met_exceeded                file_source  \
# 685693                      10.9             42.6  df_assessment_school_2022
# 685694                        15               50  df_assessment_school_2022
# 685695                      14.6             45.8  df_assessment_school_2022
# 685696                       9.2             42.5  df_assessment_school_2022
# 685697                       8.8             32.4  df_assessment_school_2022
# ...                          ...              ...                        ...
# 685796                       5.1             47.5  df_assessment_school_2022
# 685797                       6.9             46.6  df_assessment_school_2022
# 685798                        **             30.8  df_assessment_school_2022
# 685799                       5.4             43.2  df_assessment_school_2022
# 685800                       9.1             40.9  df_assessment_school_2022
#
#        file_year  updated_district_number     school_type status
# 685693      2022                    190.0  Public Charter      A
# 685694      2022                    190.0  Public Charter      A
# 685695      2022                    190.0  Public Charter      A
# 685696      2022                    190.0  Public Charter      A
# 685697      2022                    190.0  Public Charter      A
# ...          ...                      ...             ...    ...
# 685796      2022                    190.0  Public Charter      A
# 685797      2022                    190.0  Public Charter      A
# 685798      2022                    190.0  Public Charter      A
# 685799      2022                    190.0  Public Charter      A
# 685800      2022                    190.0  Public Charter      A
#
# [108 rows x 21 columns]

# %%
df_act_school_2021 = df_act_school_2021.rename(columns={'district':'district_number','school':'school_number'})
df_act_school_2020 = df_act_school_2020.rename(columns={'district':'district_number','school':'school_number'})
df_act_school_2019 = df_act_school_2019.rename(columns={'district':'district_number','school':'school_number'})
df_act_school_2018 = df_act_school_2018.rename(columns={'district':'district_number','school':'school_number'})
df_act_school_2017 = df_act_school_2017.rename(columns={'district':'district_number','school':'school_number'})
c = ['district_number', 'district_name', 'school_number', 'school_name', 'subgroup',
       'valid_tests', 'participation_rate', 'average_english_score',
       'average_math_score', 'average_reading_score', 'average_science_score',
       'average_composite_score', 'percent_scoring_21_or_higher',
       'percent_scoring_below_19']
df_to_change_and_merge('df_act_school',c)

# %%
df_profile_school_2021 = df_profile_school_2021.rename(columns={'district_id':'district_number', 'school_id':'school_number'})
df_profile_school_2020 = df_profile_school_2020.rename(columns={'district_id':'district_number', 'school_id':'school_number'})
df_profile_school_2019 = df_profile_school_2019.rename(columns={'district_id':'district_number', 'school_id':'school_number'})
df_profile_school_2018 = df_profile_school_2018.rename(columns={'district_id':'district_number', 'school_id':'school_number'})
df_profile_school_2017 = df_profile_school_2017.rename(columns={'district_id':'district_number', 'school_id':'school_number'})
df_profile_school_2016 = df_profile_school_2016.rename(columns={'district':'district_number', 'school_id':'school_number'})
df_profile_school_2015 = df_profile_school_2015.rename(columns={'district':'district_number', 'school_id':'school_number'})
df_profile_school_2014 = df_profile_school_2014.rename(columns={'district':'district_number', 'school_id':'school_number',
                                                               'free_reduced_pct':'economically_disadvantaged_pct'})
df_profile_school_2014['hawaiian_pacisld_pct'] = np.NaN
df_profile_school_2013 = df_profile_school_2013.rename(columns={'district':'district_number', 'school_no':'school_number',
                                                               'free_reduced_pct':'economically_disadvantaged_pct'})
df_profile_school_2013['hawaiian_pacisld_pct'] = np.NaN

df_profile_school_2012 = df_profile_school_2012.rename(columns={'district':'district_number', 'school':'school_number',
                                                                'free_reduced_(%)':'economically_disadvantaged_pct',
                                                                'african_american_(%)':'african_american_pct', 
                                                                'hispanic_(%)':'hispanic_pct', 
                                                                'asian_(%)':'asian_pct',
                                                                'native_american_(%)':'native_american_pct',
                                                                'white_(%)':'white_pct',
                                                                'male_(%)':'male_pct', 
                                                                'female_(%)':'female_pct'})
df_profile_school_2012['hawaiian_pacisld_pct'] = np.NaN
df_profile_school_2012['limited_english_proficient_pct'] = np.NaN
df_profile_school_2012['students_with_disabilities_pct'] = np.NaN

df_profile_school_2011 = df_profile_school_2011.rename(columns={'district':'district_number', 'school':'school_number',
                                                                'free_reduced_(%)':'economically_disadvantaged_pct',
                                                                'african_american_(%)':'african_american_pct', 
                                                                'hispanic_(%)':'hispanic_pct', 
                                                                'asian_(%)':'asian_pct',
                                                                'native_american_(%)':'native_american_pct',
                                                                'white_(%)':'white_pct',
                                                                'male_(%)':'male_pct', 
                                                                'female_(%)':'female_pct'})
df_profile_school_2011['hawaiian_pacisld_pct'] = np.NaN
df_profile_school_2011['limited_english_proficient_pct'] = np.NaN
df_profile_school_2011['students_with_disabilities_pct'] = np.NaN

df_profile_school_2010 = df_profile_school_2010.rename(columns={'district':'district_number', 'school':'school_number',
                                                                'free_reduced_(%)':'economically_disadvantaged_pct',
                                                                'african_american_(%)':'african_american_pct', 
                                                                'hispanic_(%)':'hispanic_pct', 
                                                                'asian_(%)':'asian_pct',
                                                                'native_american_(%)':'native_american_pct',
                                                                'white_(%)':'white_pct',
                                                                'male_(%)':'male_pct', 
                                                                'female_(%)':'female_pct'})
df_profile_school_2010['hawaiian_pacisld_pct'] = np.NaN
df_profile_school_2010['limited_english_proficient_pct'] = np.NaN
df_profile_school_2010['students_with_disabilities_pct'] = np.NaN

# %%
df_profile_district_2010.columns
# Out:
# Index(['year', 'district', 'district_name', 'grades_served',
#        'number_of_schools', 'administrators', 'teachers',
#        'average_daily_membership', 'total', 'white', 'african_american',
#        'hispanic', 'asian', 'native_american', 'male', 'female', 'white_(%)',
#        'african_american_(%)', 'hispanic_(%)', 'asian_(%)',
#        'native_american_(%)', 'male_(%)', 'female_(%)', 'white_male',
#        'african_american_male', 'hispanic_male', 'asian_male',
#        'native_american_male', 'white_female', 'african_american_female',
#        'hispanic_female', 'asian_female', 'native_american_female',
#        'economically_disadvantaged', 'limited_english_proficient_(%)',
#        'limited_english_proficient', 'number_exempt_from_reading_assessment',
#        'students_with_disabilities', 'students_with_disabilities_(%)',
#        'free_eligible', 'reduced_eligible', 'free_reduced_eligible',
#        'free_(%)', 'reduced_(%)', 'free_reduced_(%)', 'title_i', 'title_i_(%)',
#        'per_pupil_expenditures_per_ada', 'local_funding_(%)',
#        'federal_funding_(%)', 'state_funding_(%)',
#        'state:_per_pupil_expenditures_per_ada', 'state:_local_funding_(%)',
#        'state:_federal_funding_(%)', 'state:_state_funding_(%)'],
#       dtype='object')

# %%
columns = ['african_american', 'asian', 'female',# 'hawaiian_pacisld_pct',
       'hispanic', 'limited_english_proficient', 'male','economically_disadvantaged',
       'native_american','students_with_disabilities', 'total', 'white']
df = [df_profile_district_2010, df_profile_district_2011,df_profile_district_2012]
for d in df:
    for i in columns: 
        d[i] = d[i].replace('-','0')
        d[i] = d[i].astype('float64')

# %%
df_profile_district_2010 = df_profile_district_2010[columns]
df_profile_district_2010 = pd.DataFrame(df_profile_district_2010.sum(axis=0)).transpose()


cols = ['african_american', 'asian',
       'economically_disadvantaged', 'female',
       'hispanic', 'limited_english_proficient', 'male',
       'native_american', 'students_with_disabilities', 'total', 'white']
for i in cols:
    df_profile_district_2010[i+'_pct'] = df_profile_district_2010[i] / df_profile_district_2010['total']
    
df_profile_district_2010['district_number'] = 0
df_profile_district_2010['district_name'] = 'State of Tennessee'
df_profile_district_2010['school_number'] = 0
df_profile_district_2010['school_name'] = 'All Schools'
df_profile_district_2010['hawaiian_pacisld_pct'] = np.NaN

# %%
df_profile_district_2011 = df_profile_district_2011[columns]
df_profile_district_2011 = pd.DataFrame(df_profile_district_2011.sum(axis=0)).transpose()


cols = ['african_american', 'asian',
       'economically_disadvantaged', 'female',
       'hispanic', 'limited_english_proficient', 'male',
       'native_american', 'students_with_disabilities', 'total', 'white']
for i in cols:
    df_profile_district_2011[i+'_pct'] = df_profile_district_2011[i] / df_profile_district_2011['total']
    
df_profile_district_2011['district_number'] = 0
df_profile_district_2011['district_name'] = 'State of Tennessee'
df_profile_district_2011['school_number'] = 0
df_profile_district_2011['school_name'] = 'All Schools'
df_profile_district_2011['hawaiian_pacisld_pct'] = np.NaN

# %%
df_profile_district_2012 = df_profile_district_2012[columns]
df_profile_district_2012 = pd.DataFrame(df_profile_district_2012.sum(axis=0)).transpose()


cols = ['african_american', 'asian',
       'economically_disadvantaged', 'female',
       'hispanic', 'limited_english_proficient', 'male',
       'native_american', 'students_with_disabilities', 'total', 'white']
for i in cols:
    df_profile_district_2012[i+'_pct'] = df_profile_district_2012[i] / df_profile_district_2012['total']
    
df_profile_district_2012['district_number'] = 0
df_profile_district_2012['district_name'] = 'State of Tennessee'
df_profile_district_2012['school_number'] = 0
df_profile_district_2012['school_name'] = 'All Schools'
df_profile_district_2012['hawaiian_pacisld_pct'] = np.NaN

# %%
df_profile_district_2013.columns
# Out:
# Index(['year', 'district', 'district_name', 'grades_served',
#        'number_of_schools', 'administrators', 'teachers',
#        'average_daily_membership', 'total', 'white', 'african_american',
#        'hispanic', 'asian', 'native_american', 'male', 'female', 'white_pct',
#        'african_american_pct', 'hispanic_pct', 'asian_pct',
#        'native_american_pct', 'male_pct', 'female_pct', 'white_male',
#        'african_american_male', 'hispanic_male', 'asian_male',
#        'native_american_male', 'white_female', 'african_american_female',
#        'hispanic_female', 'asian_female', 'native_american_female',
#        'limited_english_proficient_pct', 'limited_english_proficient',
#        'number_exempt_from_reading_assessment', 'students_with_disabilities',
#        'students_with_disabilities_pct', 'free_eligible', 'reduced_eligible',
#        'free_reduced_eligible', 'free_pct', 'reduced_pct', 'free_reduced_pct',
#        'title_i', 'title_i_pct', 'per_pupil_expenditures_per_ada',
#        'local_funding_pct', 'federal_funding_pct', 'state_funding_pct',
#        'state_per_pupil_expenditures_per_ada', 'state_local_funding_pct',
#        'state_federal_funding_pct', 'state_state_funding_pct'],
#       dtype='object')

# %%
df_profile_district_2013 = df_profile_district_2013.loc[df_profile_district_2013['district']==0].copy()
df_profile_district_2013 = df_profile_district_2013.rename(columns={'district':'district_number','free_reduced_pct':'economically_disadvantaged_pct'})
df_profile_district_2013['school_name'] = 'All Schools'
df_profile_district_2013['school_number'] = 0
df_profile_district_2013['hawaiian_pacisld_pct'] = np.NaN

df_profile_district_2018 = df_profile_district_2018.loc[df_profile_district_2018['district']==0].copy()
df_profile_district_2018 = df_profile_district_2018.rename(columns={'district':'district_number'})
df_profile_district_2018['school_name'] = 'All Schools'
df_profile_district_2018['school_number'] = 0

df_profile_district_2019 = df_profile_district_2019.loc[df_profile_district_2019['district_id']==0].copy()
df_profile_district_2019 = df_profile_district_2019.rename(columns={'district_id':'district_number'})
df_profile_district_2019['school_name'] = 'All Schools'
df_profile_district_2019['school_number'] = 0

df_profile_district_2020 = df_profile_district_2020.loc[df_profile_district_2020['district_id']==0].copy()
df_profile_district_2020 = df_profile_district_2020.rename(columns={'district_id':'district_number'})
df_profile_district_2020['school_name'] = 'All Schools'
df_profile_district_2020['school_number'] = 0

df_profile_district_2021 = df_profile_district_2021.loc[df_profile_district_2021['district_id']==0].copy()
df_profile_district_2021 = df_profile_district_2021.rename(columns={'district_id':'district_number'})
df_profile_district_2021['school_name'] = 'All Schools'
df_profile_district_2021['school_number'] = 0

# %%
df_profile_school_2019.loc[df_profile_school_2019['school_number']==1]
# Out:
#      school_year  district_number                        district_name  \
# 52       2018-19              793  Arlington Municipal School District
# 906      2018-19              190       Metro Nashville Public Schools
# 1214     2018-19              750            Rutherford County Schools
#
#       school_number                 school_name grades_served  safe_school  \
# 52                1              Arlington High   Grades 9-12  SAFE SCHOOL
# 906               1     A. Z. Kelley Elementary   Grades PK-4  SAFE SCHOOL
# 1214              1  Blackman Elementary School    Grades K-5  SAFE SCHOOL
#
#       average_daily_membership  total  female  female_pct  male  male_pct  \
# 52                      2059.0   2071    1025        49.5  1046      50.5
# 906                      797.0    795     403        50.7   392      49.3
# 1214                     985.0    961     461        48.0   500      52.0
#
#       economically_disadvantaged  economically_disadvantaged_pct  \
# 52                            97                             4.7
# 906                          306                            38.5
# 1214                         120                            12.5
#
#       limited_english_proficient  limited_english_proficient_pct  \
# 52                            12                             0.6
# 906                          248                            31.2
# 1214                          73                             7.6
#
#       students_with_disabilities  students_with_disabilities_pct  \
# 52                           184                             8.9
# 906                           88                            11.1
# 1214                          83                             8.6
#
#       african_american  african_american_pct  asian  asian_pct  \
# 52                 326                  15.7     79        3.8
# 906                287                  36.1     99       12.5
# 1214               261                  27.2    110       11.4
#
#       hawaiian_pacisld  hawaiian_pacisld_pct  hispanic  hispanic_pct  \
# 52                   4                   0.2       136           6.6
# 906                  0                   0.0       207          26.0
# 1214                 2                   0.2        92           9.6
#
#       native_american  native_american_pct  white  white_pct  \
# 52                  2                  0.1   1524       73.6
# 906                 0                  0.0    202       25.4
# 1214                4                  0.4    492       51.2
#
#       african_american_female  african_american_male  asian_female  \
# 52                        166                    160            45
# 906                       151                    136            49
# 1214                      127                    134            50
#
#       asian_male  hawaiian_pacisld_female  hawaiian_pacisld_male  \
# 52            34                        2                      2
# 906           50                        0                      0
# 1214          60                        2                      0
#
#       hispanic_female  hispanic_male  native_american_female  \
# 52                 75             61                       2
# 906               104            103                       0
# 1214               42             50                       2
#
#       native_american_male  white_female  white_male
# 52                       0           735         789
# 906                      0            99         103
# 1214                     2           238         254

# %%
c = ['african_american_pct', 'asian_pct', 'district_number', 'district_name',
       'economically_disadvantaged_pct', 'female_pct', 'hawaiian_pacisld_pct',
       'hispanic_pct', 'limited_english_proficient_pct', 'male_pct',
       'native_american_pct', 'school_number', 'school_name',
       'students_with_disabilities_pct', 'total', 'white_pct']

df_to_change_and_merge('df_profile',c)

# %%
df_profile[df_profile['district_number']==0]
# Out:
#       african_american_pct         asian_pct  district_number  \
# 7097                  24.1               2.2                0
# 9063                  24.1               2.2                0
# 11043     24.1337414097111  2.05544376297831                0
# 13001            24.140984          1.977681                0
# 22075                 24.3               2.6                0
# 22076                 23.9               2.5                0
# 22077                 24.0               2.4                0
# 22078                 24.0               2.3                0
# 22079             24.09701          1.895987                0
# 22080             0.236019          0.017948                0
# 22081             0.242081          0.019043                0
# 22082             0.242646          0.017516                0
#
#             district_name economically_disadvantaged_pct female_pct  \
# 7097   State of Tennessee                           34.7       48.6
# 9063   State of Tennessee                           35.1       48.7
# 11043  State of Tennessee                      57.901487  48.663811
# 13001  State of Tennessee                      58.771854  48.638162
# 22075  State of Tennessee                           33.5       48.8
# 22076  State of Tennessee                           30.6       48.8
# 22077  State of Tennessee                           34.9       48.8
# 22078  State of Tennessee                           36.1       48.7
# 22079  State of Tennessee                      58.617011  48.630867
# 22080  State of Tennessee                       0.583545   0.485476
# 22081  State of Tennessee                       0.564011    0.48574
# 22082  State of Tennessee                       0.566663   0.485833
#
#       hawaiian_pacisld_pct hispanic_pct limited_english_proficient_pct  \
# 7097                   0.2          9.7                            5.3
# 9063                   0.2            9                              5
# 11043    0.155739779012182     8.459552                       4.592767
# 13001                  NaN     7.788872                       4.478382
# 22075         Less than 1%         12.3                            7.8
# 22076                  0.2         11.8                            7.7
# 22077                  0.2         10.9                            4.6
# 22078                  0.2         10.4                            4.6
# 22079                  NaN     7.285433                       4.336143
# 22080                  NaN     0.066423                        0.00031
# 22081                  NaN     0.062311                       0.000331
# 22082                  NaN     0.055456                       0.000305
#
#         male_pct native_american_pct  school_number  school_name  \
# 7097        51.4                 0.3              0  All Schools
# 9063        51.3                 0.3              0  All Schools
# 11043  51.334984   0.319612970081093              0  All Schools
# 13001  51.360731            0.328222              0  All Schools
# 22075       51.2        Less than 1%              0  All Schools
# 22076       51.2                 0.4              0  All Schools
# 22077       51.2                 0.4              0  All Schools
# 22078       51.3                 0.4              0  All Schools
# 22079   51.36863            0.295392              0  All Schools
# 22080   0.514524            0.001878              0  All Schools
# 22081    0.51426            0.002773              0  All Schools
# 22082   0.514167            0.002163              0  All Schools
#
#       students_with_disabilities_pct     total  white_pct  \
# 7097                            13.9  999701.0       63.4
# 9063                              14    997893       64.2
# 11043               13.9806324380555  995892.0  64.852112
# 13001                      14.202876  993841.0  65.612306
# 22075                           13.5    957423       60.1
# 22076                           13.1    980619       61.2
# 22077                           13.5    973659       62.1
# 22078                           13.6    975222       62.7
# 22079                      13.684589  993256.0  66.269824
# 22080                       0.145143  976855.0   0.677731
# 22081                       0.139772  998223.0   0.673792
# 22082                       0.142507  972153.0   0.682219
#
#                     file_source file_year  updated_district_number  \
# 7097     df_profile_school_2017      2017                      NaN
# 9063     df_profile_school_2016      2016                      NaN
# 11043    df_profile_school_2015      2015                      NaN
# 13001    df_profile_school_2014      2014                      NaN
# 22075  df_profile_district_2021      2021                      NaN
# 22076  df_profile_district_2020      2020                      NaN
# 22077  df_profile_district_2019      2019                      NaN
# 22078  df_profile_district_2018      2018                      NaN
# 22079  df_profile_district_2013      2013                      NaN
# 22080  df_profile_district_2012      2012                      NaN
# 22081  df_profile_district_2011      2011                      NaN
# 22082  df_profile_district_2010      2010                      NaN
#
#       school_type status
# 7097          NaN    NaN
# 9063          NaN    NaN
# 11043         NaN    NaN
# 13001         NaN    NaN
# 22075         NaN    NaN
# 22076         NaN    NaN
# 22077         NaN    NaN
# 22078         NaN    NaN
# 22079         NaN    NaN
# 22080         NaN    NaN
# 22081         NaN    NaN
# 22082         NaN    NaN

# %%
df_profile.loc[df_profile['school_number']==8015]
# Out:
#       african_american_pct asian_pct  district_number  \
# 1785      Greater than 95%         *              985
# 1804                  37.9      10.9              986
# 3572                  99.3       0.0              985
# 3594                  38.6       9.6              986
# 3608                  98.7       0.0              985
# 5182                  43.8      11.8              986
# 7074                  98.8       0.0              985
# 9040                  98.7       NaN              985
# 11031                 98.4                        985
# 12987     98.2843137254902       NaN              985
# 14959            97.183099       NaN              985
# 16487            92.517007       NaN              791
# 16818            99.310345       NaN              985
# 18263                    -         -              791
# 20024                 97.9         -              791
# 21785                 99.2         -              791
#
#                             district_name economically_disadvantaged_pct  \
# 1785          Achievement School District                           67.1
# 1804   Tennessee State Board of Education                           28.4
# 3572          Achievement School District                           61.5
# 3594   Tennessee State Board of Education                           31.7
# 3608          Achievement School District                           72.9
# 5182   Tennessee State Board of Education                           27.8
# 7074          Achievement School District                           82.3
# 9040          Achievement School District                           77.6
# 11031         Achievement School District                             38
# 12987         Achievement School District                      94.362745
# 14959         Achievement School District                      83.962264
# 16487                       Memphis - old                       90.47619
# 16818         Achievement School District                      84.246575
# 18263                             Memphis                           91.1
# 20024                             Memphis                              -
# 21785                             Memphis                              -
#
#       female_pct hawaiian_pacisld_pct  hispanic_pct  \
# 1785        43.7                    *  Less than 5%
# 1804        53.6                    *          24.6
# 3572        40.7                  0.0           0.4
# 3594        55.3                  0.0          25.3
# 3608        44.1                  0.0           0.4
# 5182        52.8                  0.0          29.9
# 7074        45.3                  0.0           1.2
# 9040        48.2                  NaN           0.6
# 11031       48.9                                1.4
# 12987  53.186275                  NaN       1.22549
# 14959  55.211268                  NaN      2.535211
# 16487  58.163265                  NaN      4.761905
# 16818  60.689655                  NaN           NaN
# 18263          -                  NaN             -
# 20024       59.3                  NaN           0.7
# 21785       55.4                  NaN           0.4
#
#       limited_english_proficient_pct   male_pct native_american_pct  \
# 1785                               *       56.3                   *
# 1804                            28.2       46.4                   *
# 3572                             0.0       59.3                 0.0
# 3594                            21.2       44.7                 0.0
# 3608                             0.0       55.9                 0.0
# 5182                            22.9       47.2                 0.0
# 7074                             0.8       54.7                 0.0
# 9040                             1.6       51.8                 NaN
# 11031                                      51.1
# 12987                       0.735294  46.813725                 NaN
# 14959                            NaN  44.788732                 NaN
# 16487                            NaN  41.836735                 NaN
# 16818                            NaN  39.310345                 NaN
# 18263                            NaN          -                   -
# 20024                            NaN       40.7                   -
# 21785                            NaN       44.6                   -
#
#        school_number                               school_name  \
# 1785            8015   Humes Preparatory Academy Middle School
# 1804            8015      KIPP Antioch College Prep Elementary
# 3572            8015  Humes Preparatory Academy Middle  School
# 3594            8015      KIPP Antioch College Prep Elementary
# 3608            8015  Humes Preparatory Academy Middle  School
# 5182            8015      KIPP Antioch College Prep Elementary
# 7074            8015  Humes Preparatory Academy Middle  School
# 9040            8015  Humes Preparatory Academy Middle  School
# 11031           8015  Humes Preparatory Academy Middle  School
# 12987           8015  Humes Preparatory Academy - Upper School
# 14959           8015  Humes Preparatory Academy - Upper School
# 16487           8015           Memphis Business Academy Middle
# 16818           8015  Humes Preparatory Academy - Upper School
# 18263           8015           Memphis Business Academy Middle
# 20024           8015                  Memphis Business Academy
# 21785           8015                  Memphis Business Academy
#
#       students_with_disabilities_pct  total     white_pct  \
# 1785                            11.9    252  Less than 5%
# 1804                            10.2    422          26.5
# 3572                            13.0    270           0.4
# 3594                            10.9    293          26.6
# 3608                            16.5    236           0.8
# 5182                            15.3    144          14.6
# 7074                            16.1    254           0.0
# 9040                            14.7  313.0           0.6
# 11031                           18.1    370           0.3
# 12987               19.8529411764706  408.0      0.245098
# 14959                       19.43662  355.0       0.28169
# 16487                       7.823129  294.0           NaN
# 16818                       21.37931  145.0           NaN
# 18263                            NaN      -             -
# 20024                            NaN    145           1.4
# 21785                            NaN  240.0           0.4
#
#                   file_source file_year  updated_district_number  \
# 1785   df_profile_school_2021      2021                    985.0
# 1804   df_profile_school_2021      2021                    190.0
# 3572   df_profile_school_2020      2020                    985.0
# 3594   df_profile_school_2020      2020                    190.0
# 3608   df_profile_school_2019      2019                    985.0
# 5182   df_profile_school_2019      2019                    190.0
# 7074   df_profile_school_2018      2018                    985.0
# 9040   df_profile_school_2017      2017                    985.0
# 11031  df_profile_school_2016      2016                    985.0
# 12987  df_profile_school_2015      2015                    985.0
# 14959  df_profile_school_2014      2014                    985.0
# 16487  df_profile_school_2013      2013                    791.0
# 16818  df_profile_school_2013      2013                    985.0
# 18263  df_profile_school_2012      2012                    791.0
# 20024  df_profile_school_2011      2011                    791.0
# 21785  df_profile_school_2010      2010                    791.0
#
#           school_type status
# 1785   Public Charter      A
# 1804   Public Charter      I
# 3572   Public Charter      A
# 3594   Public Charter      I
# 3608   Public Charter      A
# 5182   Public Charter      I
# 7074   Public Charter      A
# 9040   Public Charter      A
# 11031  Public Charter      A
# 12987  Public Charter      A
# 14959  Public Charter      A
# 16487  Public Charter      I
# 16818  Public Charter      A
# 18263  Public Charter      I
# 20024  Public Charter      I
# 21785  Public Charter      I

# %%
df_profile.loc[df_profile['school_name']=='KIPP Antioch College Prep Elementary']
# Out:
#      african_american_pct asian_pct  district_number  \
# 1804                 37.9      10.9              986
# 3594                 38.6       9.6              986
# 5182                 43.8      11.8              986
#
#                            district_name economically_disadvantaged_pct  \
# 1804  Tennessee State Board of Education                           28.4
# 3594  Tennessee State Board of Education                           31.7
# 5182  Tennessee State Board of Education                           27.8
#
#      female_pct hawaiian_pacisld_pct hispanic_pct  \
# 1804       53.6                    *         24.6
# 3594       55.3                  0.0         25.3
# 5182       52.8                  0.0         29.9
#
#      limited_english_proficient_pct male_pct native_american_pct  \
# 1804                           28.2     46.4                   *
# 3594                           21.2     44.7                 0.0
# 5182                           22.9     47.2                 0.0
#
#       school_number                           school_name  \
# 1804           8015  KIPP Antioch College Prep Elementary
# 3594           8015  KIPP Antioch College Prep Elementary
# 5182           8015  KIPP Antioch College Prep Elementary
#
#      students_with_disabilities_pct total white_pct             file_source  \
# 1804                           10.2   422      26.5  df_profile_school_2021
# 3594                           10.9   293      26.6  df_profile_school_2020
# 5182                           15.3   144      14.6  df_profile_school_2019
#
#      file_year  updated_district_number     school_type status
# 1804      2021                    190.0  Public Charter      I
# 3594      2020                    190.0  Public Charter      I
# 5182      2019                    190.0  Public Charter      I
